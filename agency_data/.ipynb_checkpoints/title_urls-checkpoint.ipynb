# %%
import pandas as pd
import re
import json
import openpyxl

# %%
ers_path = 'FY2014-19 Datasets for ERS Publications.xlsx'
sheet_names = ['ATUS','Census Surveys', 'CES', 'CPS-FSS', 'Cost Est. Foodborne Illnesses'
                   , 'FDA-FSIS-AMS', 'FADS-LAFA', 'FARA', 'FICRCD-CSFII', 'FNS', 'FoodAPS'
                   ,'IRI', 'NHANES', 'Nielsen', 'Qtrly FAFH', 'SNAP Admin', 'TD Linx', 'SCH MEALS DATA']
wb = openpyxl.load_workbook(ers_path)

# %%
excel_df_list = []
for n in sheet_names:
    ws = wb[n]
    df_list = []
    for i in range(2, ws.max_row + 1):  # 2nd arg in range() not inclusive, so add 1
        title = ws.cell(row = i,column = 4).value
        datasets = ws.cell(row = i,column = 5).value
        try:
            link = ws.cell(row=i, column=4).hyperlink.target
        except:
            link = None
        ers_df = pd.DataFrame({'title':title,'pub_url':link,'dataset':datasets},index = [i])
        df_list.append(ers_df)
    sheet_df = pd.concat(df_list)
    sheet_df['sheet_name'] = n
    excel_df_list.append(sheet_df)
# df['link'] = links

# %%
a = pd.concat(excel_df_list)

# %%
b  = a.dropna(subset = ['title'])

# %%
b
# Out:
#                                                 title  \
# 2                                              Titles
# 3   The Role of Time in Fast-Food Purchasing Behav...
# 4   Americans’ Eating Patterns and Time Spent on F...
# 5   The Role of Fossil Fuels in the U.S. Food Syst...
# 6   Food Purchase Decisions of Millennial Househol...
# 7   The Association Between Nutrition Information ...
# 8   Adult Eating and Health Patterns: Evidence Fro...
# 9   Consumer Food Safety Practices: Raw Milk Consu...
# 10  Frequency and Time of Day That Americans Eat: ...
# 2                                              Titles
# 3   Participation in SNAP and Unemployment Insuran...
# 4   Measuring Access to Healthful, Affordable Food...
# 5         Annual and Monthly SNAP Participation Rates
# 6                    Food Choices and Store Proximity
# 7   Improving the Assessment of SNAP Targeting Usi...
# 8   Comparing National Food Acquisition and Purcha...
# 9   Economies of Scale, the Lunch-Breakfast Ratio,...
# 10  Low-Income and Low-Supermarket-Access Census T...
# 11  Household Food Security in the United States i...
# 12       America’s Eating Habits: Food Away From Home
# 13  Measuring the Value of the U.S. Food System: R...
# 14  Understanding Low-Income and Low-Access Census...
# 15  The Impacts of Supplemental Nutrition Assistan...
# 2                                              Titles
# 3       U.S. Households’ Demand for Convenience Foods
# 4   The Stimulus Act of 2009 and Its Effect on Foo...
# 5   Food-at-Home Expenditures: Comparing Commercia...
# 6        America’s Eating Habits: Food Away From Home
# 2                                              Titles
# 3   Participation in SNAP and Unemployment Insuran...
# ..                                                ...
# 4   Changes in Eating Patterns and Diet Quality Am...
# 5   The Cost of Satisfying Fruit and Vegetable Rec...
# 6   U.S. Food Commodity Consumption Broken Down by...
# 7   Examining an "Experimental" Food Security Stat...
# 8        America’s Eating Habits: Food Away From Home
# 9   The Association Between Restaurant Menu Label ...
# 10  Frequency and Time of Day That Americans Eat: ...
# 2                                              Titles
# 3   Trends in Infant Formula Rebate Contracts: Imp...
# 4                    Food Choices and Store Proximity
# 5   Updated Supermarket Shrink Estimates for Fresh...
# 6   Changes in Retail Organic Price Premiums from ...
# 2                                              Titles
# 3   Economies of Scale, the Lunch-Breakfast Ratio,...
# 4       U.S. Households’ Demand for Convenience Foods
# 2                                              Titles
#                                               dataset      sheet_name
# 2                                                Sets            ATUS
# 3                                       ▪2003-11 ATUS            ATUS
# 4   ▪Eating & Health Module (EHM), a supplement to...            ATUS
# 5   ▪U.S. Department of Labor, Bureau of Labor Sta...            ATUS
# 6   ▪American Time Use Survey (ATUS)/Healthy Eatin...            ATUS
# 7                        ▪Healthy Eating Index (2010)            ATUS
# 8                          ▪EHM (2006-08 and 2014-16)            ATUS
# 9                                 ▪ATUS-EHM (2014-16)            ATUS
# 10                     ▪ATUS (2014-16) ▪EHM (2014-16)            ATUS
# 2                                                Sets  Census Surveys
# 3                                          ▪CPS ▪ASEC  Census Surveys
# 4   ▪2010 Census TIGER/Line® Shapefiles ▪2010 Cens...  Census Surveys
# 5                                       ▪SIPP and ACS  Census Surveys
# 6             ▪U.S. Census Bureau (2010 Census Tract)  Census Surveys
# 7                    ▪American Community Survey (ACS)  Census Surveys
# 8   ▪Survey of Income and Program Participation (S...  Census Surveys
# 9   ▪U.S. Census Bureau (School Food Authority Cha...  Census Surveys
# 10  ▪2010 Decennial Census ▪2010-14 American Commu...  Census Surveys
# 11                                ▪U.S. Census Bureau  Census Surveys
# 12  ▪U.S. Census Bureau (Monthly Retail Trade and ...  Census Surveys
# 13  ▪U.S. Census Bureau (sales data—annual, quarte...  Census Surveys
# 14  ▪Census Bureau’s 2010-14 American Community Su...  Census Surveys
# 15  ▪U.S. Census Bureau’s Consolidated Federal Fun...  Census Surveys
# 2                                                Sets             CES
# 3   ▪Consumer Expenditure Survey of the U.S. Burea...             CES
# 4   ▪Consumer Expenditure Survey (CE) (administere...             CES
# 5                        ▪Consumer Expenditure Survey             CES
# 6                                                ▪CES             CES
# 2                                                Sets         CPS-FSS
# 3   ▪Current Population Survey Annual Social and E...         CPS-FSS
# ..                                                ...             ...
# 4   ▪National Health and Nutrition Examination Sur...          NHANES
# 5   ▪ERS analysis of data from the National Health...          NHANES
# 6   ▪WWEIA/NHANES ▪WWEIA/NHANES (1999-2008) ▪WWEIA...          NHANES
# 7                                             ▪NHANES          NHANES
# 8                                             ▪NHANES          NHANES
# 9   ▪NHANES (Flexible Consumer Behavior Survey—200...          NHANES
# 10                                  ▪NHANES (2013-16)          NHANES
# 2                                                Sets         Nielsen
# 3   ▪2008 proprietary report prepared for ERS by t...         Nielsen
# 4                ▪2010 Nielsen Homescan Panel Survey          Nielsen
# 5                          ▪Nielsen Perishables Group         Nielsen
# 6                             ▪Nielsen Homescan data          Nielsen
# 2                                                Sets      Qtrly FAFH
# 3                                                None      Qtrly FAFH
# 4                                                None      Qtrly FAFH
# 2                                                Sets      SNAP Admin
# 3                                                None      SNAP Admin
# 4                                                None      SNAP Admin
# 5                                                None      SNAP Admin
# 6                                                None      SNAP Admin
# 7   ▪Multiple administrative sources from Oregon (...      SNAP Admin
# 2                                                Sets         TD Linx
# 3                                                None         TD Linx
# 4                                                None         TD Linx
# 5                                                None         TD Linx
# 6                                                None         TD Linx
# 7                                             ▪TDLinx         TD Linx
# 2                                                Sets  SCH MEALS DATA
# 3   ▪USDA’s National Data Bank ▪State reports ▪Spe...  SCH MEALS DATA
# 4   ▪School Food Authority Characteristics Study (...  SCH MEALS DATA
#
# [139 rows x 4 columns]

# %%
b.to_csv('ers_url_linkages.csv',index = False)
